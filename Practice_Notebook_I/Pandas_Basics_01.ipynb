# %%
import pandas as pd

# %% [markdown]
# # Pandas DataFrame Basics-1

# %% [markdown]
# ## Creating Pandas DataFrame from CSV file

# %%
pd.read_csv('/Users/siddhantraj/Desktop/Python/Python Udemy/Pandas Bootcamp _Data Science/Course_Materials_Part1/Video_Lecture_NBs/titanic.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic = pd.read_csv('/Users/siddhantraj/Desktop/Python/Python Udemy/Pandas Bootcamp _Data Science/Course_Materials_Part1/Video_Lecture_NBs/titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Pandas Display Options and Methods head() and tail()

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows = 60

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.min_rows = 9

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked deck
# 889         1       1  male  26.0      0      0  30.00        C    C
# 890         0       3  male  32.0      0      0   7.75        Q  NaN

# %% [markdown]
# ## Data Inspection

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked deck
# count   891.000000      889  203
# ...

# %%
titanic.describe(include = 'O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# ## Python Built-in Functions and DataFrames Attributes and Methods

# %% [markdown]
# ### Python Built-in Functions

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titanic)
# Out:
# 891

# %%
round(titanic,0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(titanic)
# Out:
# 'age'

# %% [markdown]
# ### DataFrame Attributes

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# ### DataFrame Methods

# %%
titanic.head(n=2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.min()
# Out:
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare           0.0
# dtype: object

# %% [markdown]
# ### Method Chaining

# %%
titanic.mean().sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %%
titanic.std().sort_values().tail(2)
# Out:
# age     14.526497
# fare    49.693429
# dtype: float64

# %% [markdown]
# ## Selecting Columns

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['age'] # Selecting a single column
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
#        ...
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(titanic['age'])
# Out:
# pandas.core.series.Series

# %%
titanic[['age','sex']] # Selecting multiple columns
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# ..    ...     ...
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic[['age','sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic[['age','sex','fare']]
# Out:
#       age     sex     fare
# 0    22.0    male   7.2500
# 1    38.0  female  71.2833
# 2    26.0  female   7.9250
# 3    35.0  female  53.1000
# ..    ...     ...      ...
# 887  19.0  female  30.0000
# 888   NaN  female  23.4500
# 889  26.0    male  30.0000
# 890  32.0    male   7.7500
#
# [891 rows x 3 columns]

# %%
titanic[['age']] # Selecting single column in a format
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# ..    ...
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
type(titanic[['age']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Selecting Columns with 'dot notation'

# %%
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
#        ...
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.age.equals(titanic[['age']])
# Out:
# False

# %%
titanic.age.equals(titanic['age'])
# Out:
# True

# %% [markdown]
# ## Position-based indexing and slicing using iloc[]

# %%
summer = pd.read_csv('/Users/siddhantraj/Desktop/Python/Python Udemy/Pandas Bootcamp _Data Science/Course_Materials_Part1/Video_Lecture_NBs/summer.csv',index_col = 'Athlete')

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred                 HUN    Men              100M Freestyle    Gold
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# ### selecting rows with iloc[]

# %%
summer.iloc[0] # Selecting single row
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
type(summer.iloc[0])
# Out:
# pandas.core.series.Series

# %%
summer.iloc[[0]] # selecting single row in a format
# Out:
#                Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
#                         Event Medal
# Athlete
# HAJOS, Alfred  100M Freestyle  Gold

# %%
type(summer.iloc[[0]])
# Out:
# pandas.core.frame.DataFrame

# %%
summer.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
summer.iloc[[1,2,3]] # Selecting multiple rows
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
summer.iloc[1:4] # Slicing rows
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
summer.iloc[:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.iloc[-5:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
summer.iloc[[2,45,5467]]
# Out:
#                    Year       City       Sport   Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios  1896     Athens    Aquatics     Swimming     GRE    Men
# PERSAKIS, Ioannis  1896     Athens   Athletics    Athletics     GRE    Men
# POLAK, Ans         1928  Amsterdam  Gymnastics  Artistic G.     NED  Women
#
#                                         Event   Medal
# Athlete
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze
# PERSAKIS, Ioannis                 Triple Jump  Bronze
# POLAK, Ans                   Team Competition    Gold

# %% [markdown]
# ### Indexing/Slicing Rows and Columns with iloc[]

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
summer.iloc[0,3] # selecting rows and columns
# Out:
# 'Swimming'

# %%
summer.iloc[0,:3] # selecting rows and slicing columns
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0,[0,1,2]] # selecting single row and selecting multiple columns
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0,:3].equals(summer.iloc[0,[0,1,2]])
# Out:
# True

# %%
summer.iloc[:,4].equals(summer.Country)
# Out:
# True

# %% [markdown]
# ## Label-based Indexing and Slicing with loc[]

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred                 HUN    Men              100M Freestyle    Gold
# ...

# %% [markdown]
# ### selecting rows with loc[]

# %%
summer.iloc[2] # selecting single row using index
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['DRIVAS, Dimitrios'] # selecting single row using row label
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %% [markdown]
# ### Indexing/Slicing Rows and Columns with loc[]

# %%
summer.loc['PHELPS, Michael','Medal'] # selecting single row and column
# Out:
# Athlete
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# Name: Medal, dtype: object

# %%
summer.loc['PHELPS, Michael',['Medal','Event']] # selecting single row and multiple columns
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# ...

# %%
summer.loc[:,['Medal','Event']] # Slicing rows and selecting multiple columns
# Out:
#                             Medal                       Event
# Athlete
# HAJOS, Alfred                Gold              100M Freestyle
# HERSCHMANN, Otto           Silver              100M Freestyle
# DRIVAS, Dimitrios          Bronze  100M Freestyle For Sailors
# MALOKINIS, Ioannis           Gold  100M Freestyle For Sailors
# ...                           ...                         ...
# REZAEI, Ghasem Gholamreza    Gold                    Wg 96 KG
# TOTROV, Rustam             Silver                    Wg 96 KG
# ALEKSANYAN, Artur          Bronze                    Wg 96 KG
# LIDBERG, Jimmy             Bronze                    Wg 96 KG
#
# [31165 rows x 2 columns]

# %% [markdown]
# ## Summary and Outlook

# %% [markdown]
# ### Importing from CSV and First Inspection

# %%
import pandas as pd

# %%
summer = pd.read_csv('Summer_Copy.csv',index_col = 'Athlete')

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred                 HUN    Men              100M Freestyle    Gold
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# ### Selecting one column

# %%
summer.Medal
# Out:
# Athlete
# HAJOS, Alfred                  Gold
# HERSCHMANN, Otto             Silver
# DRIVAS, Dimitrios            Bronze
# MALOKINIS, Ioannis             Gold
#                               ...
# REZAEI, Ghasem Gholamreza      Gold
# TOTROV, Rustam               Silver
# ALEKSANYAN, Artur            Bronze
# LIDBERG, Jimmy               Bronze
# Name: Medal, Length: 31165, dtype: object

# %%
summer['Medal']
# Out:
# Athlete
# HAJOS, Alfred                  Gold
# HERSCHMANN, Otto             Silver
# DRIVAS, Dimitrios            Bronze
# MALOKINIS, Ioannis             Gold
#                               ...
# REZAEI, Ghasem Gholamreza      Gold
# TOTROV, Rustam               Silver
# ALEKSANYAN, Artur            Bronze
# LIDBERG, Jimmy               Bronze
# Name: Medal, Length: 31165, dtype: object

# %%
summer.loc[:,['Year','Medal']]
# Out:
#                            Year   Medal
# Athlete
# HAJOS, Alfred              1896    Gold
# HERSCHMANN, Otto           1896  Silver
# DRIVAS, Dimitrios          1896  Bronze
# MALOKINIS, Ioannis         1896    Gold
# ...                         ...     ...
# REZAEI, Ghasem Gholamreza  2012    Gold
# TOTROV, Rustam             2012  Silver
# ALEKSANYAN, Artur          2012  Bronze
# LIDBERG, Jimmy             2012  Bronze
#
# [31165 rows x 2 columns]

# %% [markdown]
# ### Selecting positional Rows

# %%
summer.iloc[10:21]
# Out:
#                     Year    City      Sport Discipline Country Gender  \
# Athlete
# PEPANOS, Antonios   1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis       1896  Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos    1896  Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas       1896  Athens  Athletics  Athletics     USA    Men
# HOFMANN, Fritz      1896  Athens  Athletics  Athletics     GER    Men
# CURTIS, Thomas      1896  Athens  Athletics  Athletics     USA    Men
# GOULDING, Grantley  1896  Athens  Athletics  Athletics     GBR    Men
# LERMUSIAUX, Albin   1896  Athens  Athletics  Athletics     FRA    Men
# FLACK, Edwin        1896  Athens  Athletics  Athletics     AUS    Men
# BLAKE, Arthur       1896  Athens  Athletics  Athletics     USA    Men
# GMELIN, Charles     1896  Athens  Athletics  Athletics     GBR    Men
#
#                              Event   Medal
# Athlete
# PEPANOS, Antonios   400M Freestyle  Silver
# ...

# %% [markdown]
# ### Selecting labeled rows

# %%
summer.loc['PEPANOS, Antonios':'GMELIN, Charles']
# Out:
#                     Year    City      Sport Discipline Country Gender  \
# Athlete
# PEPANOS, Antonios   1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis       1896  Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos    1896  Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas       1896  Athens  Athletics  Athletics     USA    Men
# HOFMANN, Fritz      1896  Athens  Athletics  Athletics     GER    Men
# CURTIS, Thomas      1896  Athens  Athletics  Athletics     USA    Men
# GOULDING, Grantley  1896  Athens  Athletics  Athletics     GBR    Men
# LERMUSIAUX, Albin   1896  Athens  Athletics  Athletics     FRA    Men
# FLACK, Edwin        1896  Athens  Athletics  Athletics     AUS    Men
# BLAKE, Arthur       1896  Athens  Athletics  Athletics     USA    Men
# GMELIN, Charles     1896  Athens  Athletics  Athletics     GBR    Men
#
#                              Event   Medal
# Athlete
# PEPANOS, Antonios   400M Freestyle  Silver
# ...

# %%
summer.loc['PEPANOS, Antonios']
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  GRE
# Gender                   Men
# Event         400M Freestyle
# Medal                 Silver
# Name: PEPANOS, Antonios, dtype: object

# %% [markdown]
# ### Putting it all together

# %%
summer[['Year','Event','Medal']].loc['LEWIS, Carl']
# Out:
#              Year         Event   Medal
# Athlete
# LEWIS, Carl  1984          100M    Gold
# LEWIS, Carl  1984          200M    Gold
# LEWIS, Carl  1984  4X100M Relay    Gold
# LEWIS, Carl  1984     Long Jump    Gold
# LEWIS, Carl  1988          100M    Gold
# LEWIS, Carl  1988          200M  Silver
# LEWIS, Carl  1988     Long Jump    Gold
# LEWIS, Carl  1992  4X100M Relay    Gold
# LEWIS, Carl  1992     Long Jump    Gold
# LEWIS, Carl  1996     Long Jump    Gold

# %%
summer.loc['LEWIS, Carl'][['Year','Event','Medal']]
# Out:
#              Year         Event   Medal
# Athlete
# LEWIS, Carl  1984          100M    Gold
# LEWIS, Carl  1984          200M    Gold
# LEWIS, Carl  1984  4X100M Relay    Gold
# LEWIS, Carl  1984     Long Jump    Gold
# LEWIS, Carl  1988          100M    Gold
# LEWIS, Carl  1988          200M  Silver
# LEWIS, Carl  1988     Long Jump    Gold
# LEWIS, Carl  1992  4X100M Relay    Gold
# LEWIS, Carl  1992     Long Jump    Gold
# LEWIS, Carl  1996     Long Jump    Gold

# %%
summer.loc['LEWIS, Carl',['Year','Event','Medal']]
# Out:
#              Year         Event   Medal
# Athlete
# LEWIS, Carl  1984          100M    Gold
# LEWIS, Carl  1984          200M    Gold
# LEWIS, Carl  1984  4X100M Relay    Gold
# LEWIS, Carl  1984     Long Jump    Gold
# LEWIS, Carl  1988          100M    Gold
# LEWIS, Carl  1988          200M  Silver
# LEWIS, Carl  1988     Long Jump    Gold
# LEWIS, Carl  1992  4X100M Relay    Gold
# LEWIS, Carl  1992     Long Jump    Gold
# LEWIS, Carl  1996     Long Jump    Gold
