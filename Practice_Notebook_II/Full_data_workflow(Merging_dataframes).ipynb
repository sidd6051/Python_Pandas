# %% [markdown]
# # Merging, Joining and Concatenating DataFrames

# %% [markdown]
# ## Adding / Concatenating Rows (Part 1)

# %%
import pandas as pd

# %%
men2004 = pd.read_csv('men2004_copy.csv')

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008 = pd.read_csv('men2008_copy.csv')

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.append(men2008, ignore_index = True)
# Out:
#               Athlete  Medals
# 0     PHELPS, Michael       8
# 1         THORPE, Ian       4
# 2    SCHOEMAN, Roland       3
# 3      PEIRSOL, Aaron       3
# 4        CROCKER, Ian       3
# ..                ...     ...
# 116  LAGUNOV, Evgeniy       1
# 117     BERENS, Ricky       1
# 118      LURZ, Thomas       1
# 119   MALLET, Gregory       1
# 120        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
pd.options.display.min_rows = 30

# %%
pd.concat([men2004, men2008], ignore_index = False)
# Out:
#                        Athlete  Medals
# 0              PHELPS, Michael       8
# 1                  THORPE, Ian       4
# 2             SCHOEMAN, Roland       3
# 3               PEIRSOL, Aaron       3
# 4                 CROCKER, Ian       3
# 5             KITAJIMA, Kosuke       3
# 6              HANSEN, Brendan       3
# 7   VAN DEN HOOGENBAND, Pieter       3
# 8               HACKETT, Grant       3
# 9               MORITA, Tomomi       2
# 10                LEZAK, Jason       2
# 11               ROGAN, Markus       2
# 12               KELLER, Klete       2
# 13              HALL, Gary Jr.       2
# 14                LOCHTE, Ryan       2
# ..                         ...     ...
# 47             DELANEY, Ashley       1
# 48                FFROST, Nick       1
# 49               FUJII, Takuro       1
# 50              GANGLOFF, Mark       1
# 51               GILOT, Fabien       1
# 52             HANSEN, Brendan       1
# 53              IZOTOV, Danila       1
# ...

# %%
pd.concat([men2004, men2008], ignore_index = True)
# Out:
#                         Athlete  Medals
# 0               PHELPS, Michael       8
# 1                   THORPE, Ian       4
# 2              SCHOEMAN, Roland       3
# 3                PEIRSOL, Aaron       3
# 4                  CROCKER, Ian       3
# 5              KITAJIMA, Kosuke       3
# 6               HANSEN, Brendan       3
# 7    VAN DEN HOOGENBAND, Pieter       3
# 8                HACKETT, Grant       3
# 9                MORITA, Tomomi       2
# 10                 LEZAK, Jason       2
# 11                ROGAN, Markus       2
# 12                KELLER, Klete       2
# 13               HALL, Gary Jr.       2
# 14                 LOCHTE, Ryan       2
# ..                          ...     ...
# 106             DELANEY, Ashley       1
# 107                FFROST, Nick       1
# 108               FUJII, Takuro       1
# 109              GANGLOFF, Mark       1
# 110               GILOT, Fabien       1
# 111             HANSEN, Brendan       1
# ...

# %%
pd.concat([men2004, men2008], ignore_index = False, keys = [2004, 2008])
# Out:
#                             Athlete  Medals
# 2004 0              PHELPS, Michael       8
#      1                  THORPE, Ian       4
#      2             SCHOEMAN, Roland       3
#      3               PEIRSOL, Aaron       3
#      4                 CROCKER, Ian       3
#      5             KITAJIMA, Kosuke       3
#      6              HANSEN, Brendan       3
#      7   VAN DEN HOOGENBAND, Pieter       3
#      8               HACKETT, Grant       3
#      9               MORITA, Tomomi       2
#      10                LEZAK, Jason       2
#      11               ROGAN, Markus       2
#      12               KELLER, Klete       2
#      13              HALL, Gary Jr.       2
#      14                LOCHTE, Ryan       2
# ...                             ...     ...
# 2008 47             DELANEY, Ashley       1
#      48                FFROST, Nick       1
#      49               FUJII, Takuro       1
#      50              GANGLOFF, Mark       1
# ...

# %%
pd.concat([men2004, men2008], ignore_index = True, keys = [2004, 2008])
# Out:
#                         Athlete  Medals
# 0               PHELPS, Michael       8
# 1                   THORPE, Ian       4
# 2              SCHOEMAN, Roland       3
# 3                PEIRSOL, Aaron       3
# 4                  CROCKER, Ian       3
# 5              KITAJIMA, Kosuke       3
# 6               HANSEN, Brendan       3
# 7    VAN DEN HOOGENBAND, Pieter       3
# 8                HACKETT, Grant       3
# 9                MORITA, Tomomi       2
# 10                 LEZAK, Jason       2
# 11                ROGAN, Markus       2
# 12                KELLER, Klete       2
# 13               HALL, Gary Jr.       2
# 14                 LOCHTE, Ryan       2
# ..                          ...     ...
# 106             DELANEY, Ashley       1
# 107                FFROST, Nick       1
# 108               FUJII, Takuro       1
# 109              GANGLOFF, Mark       1
# 110               GILOT, Fabien       1
# 111             HANSEN, Brendan       1
# ...

# %%
pd.concat([men2004, men2008], ignore_index = False, keys = [2004, 2008], names = ['Year'])
# Out:
#                             Athlete  Medals
# Year
# 2004 0              PHELPS, Michael       8
#      1                  THORPE, Ian       4
#      2             SCHOEMAN, Roland       3
#      3               PEIRSOL, Aaron       3
#      4                 CROCKER, Ian       3
#      5             KITAJIMA, Kosuke       3
#      6              HANSEN, Brendan       3
#      7   VAN DEN HOOGENBAND, Pieter       3
#      8               HACKETT, Grant       3
#      9               MORITA, Tomomi       2
#      10                LEZAK, Jason       2
#      11               ROGAN, Markus       2
#      12               KELLER, Klete       2
#      13              HALL, Gary Jr.       2
#      14                LOCHTE, Ryan       2
# ...                             ...     ...
# 2008 47             DELANEY, Ashley       1
#      48                FFROST, Nick       1
#      49               FUJII, Takuro       1
#      50              GANGLOFF, Mark       1
# ...

# %%
men0408 = pd.concat([men2004, men2008], ignore_index = False, keys = [2004, 2008], names = ['Year'])

# %%
men0408
# Out:
#                             Athlete  Medals
# Year
# 2004 0              PHELPS, Michael       8
#      1                  THORPE, Ian       4
#      2             SCHOEMAN, Roland       3
#      3               PEIRSOL, Aaron       3
#      4                 CROCKER, Ian       3
#      5             KITAJIMA, Kosuke       3
#      6              HANSEN, Brendan       3
#      7   VAN DEN HOOGENBAND, Pieter       3
#      8               HACKETT, Grant       3
#      9               MORITA, Tomomi       2
#      10                LEZAK, Jason       2
#      11               ROGAN, Markus       2
#      12               KELLER, Klete       2
#      13              HALL, Gary Jr.       2
#      14                LOCHTE, Ryan       2
# ...                             ...     ...
# 2008 47             DELANEY, Ashley       1
#      48                FFROST, Nick       1
#      49               FUJII, Takuro       1
#      50              GANGLOFF, Mark       1
# ...

# %% [markdown]
# ## Adding / Concatenating Rows (Part 2)

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.columns = ['Name', 'Medals']

# %%
men2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2004['success'] = 'Yes'

# %%
men2004.head()
# Out:
#                Name  Medals success
# 0   PHELPS, Michael       8     Yes
# 1       THORPE, Ian       4     Yes
# 2  SCHOEMAN, Roland       3     Yes
# 3    PEIRSOL, Aaron       3     Yes
# 4      CROCKER, Ian       3     Yes

# %%
pd.concat([men2004, men2008], ignore_index = False, keys = [2004, 2008], names = ['Year'])
# Out:
#                                Name  Medals success           Athlete
# Year
# 2004 0              PHELPS, Michael       8     Yes               NaN
#      1                  THORPE, Ian       4     Yes               NaN
#      2             SCHOEMAN, Roland       3     Yes               NaN
#      3               PEIRSOL, Aaron       3     Yes               NaN
#      4                 CROCKER, Ian       3     Yes               NaN
#      5             KITAJIMA, Kosuke       3     Yes               NaN
#      6              HANSEN, Brendan       3     Yes               NaN
#      7   VAN DEN HOOGENBAND, Pieter       3     Yes               NaN
#      8               HACKETT, Grant       3     Yes               NaN
#      9               MORITA, Tomomi       2     Yes               NaN
#      10                LEZAK, Jason       2     Yes               NaN
#      11               ROGAN, Markus       2     Yes               NaN
# ...

# %%
men2004.drop(columns = ['success'], inplace = True)

# %%
men2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2004.columns = men2008.columns

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
pd.concat([men2004, men2008], keys = [2004, 2008], names = ['Year'])
# Out:
#                             Athlete  Medals
# Year
# 2004 0              PHELPS, Michael       8
#      1                  THORPE, Ian       4
#      2             SCHOEMAN, Roland       3
#      3               PEIRSOL, Aaron       3
#      4                 CROCKER, Ian       3
#      5             KITAJIMA, Kosuke       3
#      6              HANSEN, Brendan       3
#      7   VAN DEN HOOGENBAND, Pieter       3
#      8               HACKETT, Grant       3
#      9               MORITA, Tomomi       2
#      10                LEZAK, Jason       2
#      11               ROGAN, Markus       2
#      12               KELLER, Klete       2
#      13              HALL, Gary Jr.       2
#      14                LOCHTE, Ryan       2
# ...                             ...     ...
# 2008 47             DELANEY, Ashley       1
#      48                FFROST, Nick       1
#      49               FUJII, Takuro       1
#      50              GANGLOFF, Mark       1
# ...

# %%
men2004 = pd.read_csv('men2004_copy.csv', index_col = 'Athlete')
men2008 = pd.read_csv('men2008_copy.csv', index_col = 'Athlete')

# %%
men2004.head()
# Out:
#                   Medals
# Athlete
# PHELPS, Michael        8
# THORPE, Ian            4
# SCHOEMAN, Roland       3
# PEIRSOL, Aaron         3
# CROCKER, Ian           3

# %%
men2008.head()
# Out:
#                      Medals
# Athlete
# PHELPS, Michael           8
# LOCHTE, Ryan              4
# BERNARD, Alain            3
# SULLIVAN, Eamon           3
# LAUTERSTEIN, Andrew       3

# %%
pd.concat([men2004, men2008], ignore_index = False, keys = [2004, 2008])
# Out:
#                                  Medals
#      Athlete
# 2004 PHELPS, Michael                  8
#      THORPE, Ian                      4
#      SCHOEMAN, Roland                 3
#      PEIRSOL, Aaron                   3
#      CROCKER, Ian                     3
#      KITAJIMA, Kosuke                 3
#      HANSEN, Brendan                  3
#      VAN DEN HOOGENBAND, Pieter       3
#      HACKETT, Grant                   3
#      MORITA, Tomomi                   2
#      LEZAK, Jason                     2
#      ROGAN, Markus                    2
#      KELLER, Klete                    2
#      HALL, Gary Jr.                   2
#      LOCHTE, Ryan                     2
# ...                                 ...
# 2008 DELANEY, Ashley                  1
#      FFROST, Nick                     1
#      FUJII, Takuro                    1
#      GANGLOFF, Mark                   1
#      GILOT, Fabien                    1
#      HANSEN, Brendan                  1
# ...

# %% [markdown]
# # Arithematic between Pandas Objects / Data Alignment

# %%
topfive_2004 = pd.read_csv('topfive_2004_copy.csv')

# %%
topfive_2008 = pd.read_csv('topfive_2008_copy.csv')

# %%
topfive_2004
# Out:
#             Athlete  Gold  Silver  Bronze
# 0   PHELPS, Michael   6.0     0.0     2.0
# 1    PEIRSOL, Aaron   3.0     0.0     0.0
# 2       THORPE, Ian   2.0     1.0     1.0
# 3  KITAJIMA, Kosuke   2.0     0.0     1.0
# 4    HACKETT, Grant   1.0     2.0     0.0

# %%
topfive_2008
# Out:
#             Athlete  Gold  Silver  bronze
# 0   PHELPS, Michael   8.0     0.0     0.0
# 1     GREVERS, Matt   2.0     1.0     0.0
# 2    PEIRSOL, Aaron   2.0     1.0     0.0
# 3      LOCHTE, Ryan   2.0     0.0     2.0
# 4  KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
topfive_2004.set_index('Athlete', inplace = True)

# %%
topfive_2004.head()
# Out:
#                   Gold  Silver  Bronze
# Athlete
# PHELPS, Michael    6.0     0.0     2.0
# PEIRSOL, Aaron     3.0     0.0     0.0
# THORPE, Ian        2.0     1.0     1.0
# KITAJIMA, Kosuke   2.0     0.0     1.0
# HACKETT, Grant     1.0     2.0     0.0

# %%
topfive_2008.set_index('Athlete', inplace = True)

# %%
topfive_2008.head()
# Out:
#                   Gold  Silver  bronze
# Athlete
# PHELPS, Michael    8.0     0.0     0.0
# GREVERS, Matt      2.0     1.0     0.0
# PEIRSOL, Aaron     2.0     1.0     0.0
# LOCHTE, Ryan       2.0     0.0     2.0
# KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
topfive_2004 + topfive_2008
# Out:
#                   Bronze  Gold  Silver  bronze
# Athlete
# GREVERS, Matt        NaN   NaN     NaN     NaN
# HACKETT, Grant       NaN   NaN     NaN     NaN
# KITAJIMA, Kosuke     NaN   4.0     0.0     NaN
# LOCHTE, Ryan         NaN   NaN     NaN     NaN
# PEIRSOL, Aaron       NaN   5.0     1.0     NaN
# PHELPS, Michael      NaN  14.0     0.0     NaN
# THORPE, Ian          NaN   NaN     NaN     NaN

# %%
topfive_2004.add(topfive_2008, fill_value = 0)
# Out:
#                   Bronze  Gold  Silver  bronze
# Athlete
# GREVERS, Matt        NaN   2.0     1.0     0.0
# HACKETT, Grant       0.0   1.0     2.0     NaN
# KITAJIMA, Kosuke     1.0   4.0     0.0     1.0
# LOCHTE, Ryan         NaN   2.0     0.0     2.0
# PEIRSOL, Aaron       0.0   5.0     1.0     0.0
# PHELPS, Michael      2.0  14.0     0.0     0.0
# THORPE, Ian          1.0   2.0     1.0     NaN

# %%
topfive_2004.rename(columns = {'bronze':'Bronze'}, inplace = True)

# %%
topfive_2004.rename(columns = {'Bronze':'bronze'}, inplace = True)

# %%
topfive_2008
# Out:
#                   Gold  Silver  bronze
# Athlete
# PHELPS, Michael    8.0     0.0     0.0
# GREVERS, Matt      2.0     1.0     0.0
# PEIRSOL, Aaron     2.0     1.0     0.0
# LOCHTE, Ryan       2.0     0.0     2.0
# KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
topfive_2004
# Out:
#                   Gold  Silver  bronze
# Athlete
# PHELPS, Michael    6.0     0.0     2.0
# PEIRSOL, Aaron     3.0     0.0     0.0
# THORPE, Ian        2.0     1.0     1.0
# KITAJIMA, Kosuke   2.0     0.0     1.0
# HACKETT, Grant     1.0     2.0     0.0

# %%
topfive_2004.add(topfive_2008, fill_value = 0)
# Out:
#                   Gold  Silver  bronze
# Athlete
# GREVERS, Matt      2.0     1.0     0.0
# HACKETT, Grant     1.0     2.0     0.0
# KITAJIMA, Kosuke   4.0     0.0     2.0
# LOCHTE, Ryan       2.0     0.0     2.0
# PEIRSOL, Aaron     5.0     1.0     0.0
# PHELPS, Michael   14.0     0.0     2.0
# THORPE, Ian        2.0     1.0     1.0

# %% [markdown]
# # Outer Join

# %%
men2004 = pd.read_csv('men2004_copy.csv')

# %%
men2008 = pd.read_csv('men2008_copy.csv')

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008[men2008['Athlete'] == 'THORPE, Ian']
# Out:
# Empty DataFrame
# Columns: [Athlete, Medals]
# Index: []

# %%
men2004.shape
# Out:
# (59, 2)

# %%
men2008.shape
# Out:
# (62, 2)

# %%
len(men2004) + len(men2008)
# Out:
# 121

# %%
men2004.merge(men2008, how = 'outer', on = 'Athlete').shape
# Out:
# (105, 3)

# %%
men2004.merge(men2008, how = 'outer', on = 'Athlete', suffixes = ('_2004','_2008'),indicator = True)
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 0               PHELPS, Michael          8.0          8.0        both
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 3                PEIRSOL, Aaron          3.0          3.0        both
# 4                  CROCKER, Ian          3.0          1.0        both
# 5              KITAJIMA, Kosuke          3.0          3.0        both
# 6               HANSEN, Brendan          3.0          1.0        both
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 8                HACKETT, Grant          3.0          2.0        both
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 10                 LEZAK, Jason          2.0          3.0        both
# 11                ROGAN, Markus          2.0          NaN   left_only
# ...

# %%
men0408 = men2004.merge(men2008, how = 'outer', on = 'Athlete', suffixes = ('_2004','_2008'),indicator = True)

# %%
men0408
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 0               PHELPS, Michael          8.0          8.0        both
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 3                PEIRSOL, Aaron          3.0          3.0        both
# 4                  CROCKER, Ian          3.0          1.0        both
# 5              KITAJIMA, Kosuke          3.0          3.0        both
# 6               HANSEN, Brendan          3.0          1.0        both
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 8                HACKETT, Grant          3.0          2.0        both
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 10                 LEZAK, Jason          2.0          3.0        both
# 11                ROGAN, Markus          2.0          NaN   left_only
# ...

# %%
men0408._merge.value_counts()
# Out:
# right_only    46
# left_only     43
# both          16
# Name: _merge, dtype: int64

# %% [markdown]
# # Inner Join

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.merge(men2008, how = 'inner',suffixes = ('_2004','_2008'),indicator = True)
# Out:
#             Athlete  Medals _merge
# 0   PHELPS, Michael       8   both
# 1    PEIRSOL, Aaron       3   both
# 2  KITAJIMA, Kosuke       3   both
# 3       VENDT, Erik       1   both
# 4     DAVIES, David       1   both
# 5    GANGLOFF, Mark       1   both
# 6    JENSEN, Larsen       1   both

# %% [markdown]
# # Outer Join without Intersection

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men0408 = men2004.merge(men2008, how = 'outer', on = 'Athlete', suffixes = ('_2004','_2008'), indicator = True)

# %%
men0408
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 0               PHELPS, Michael          8.0          8.0        both
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 3                PEIRSOL, Aaron          3.0          3.0        both
# 4                  CROCKER, Ian          3.0          1.0        both
# 5              KITAJIMA, Kosuke          3.0          3.0        both
# 6               HANSEN, Brendan          3.0          1.0        both
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 8                HACKETT, Grant          3.0          2.0        both
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 10                 LEZAK, Jason          2.0          3.0        both
# 11                ROGAN, Markus          2.0          NaN   left_only
# ...

# %%
men0408.loc[men0408['_merge'] != 'both']
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 11                ROGAN, Markus          2.0          NaN   left_only
# 13               HALL, Gary Jr.          2.0          NaN   left_only
# 15                 WALKER, Neil          2.0          NaN   left_only
# 16            YAMAMOTO, Takashi          2.0          NaN   left_only
# 17           SPRENGER, Nicholas          1.0          NaN   left_only
# 18           OKUMURA, Yoshihiro          1.0          NaN   left_only
# 19               PARRY, Stephen          1.0          NaN   left_only
# 20                PEARSON, Todd          1.0          NaN   left_only
# ...

# %% [markdown]
# # Left Join without Intersection

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men0408 = men2004.merge(men2008, how = 'outer', on = 'Athlete', suffixes = ('_2004', '_2008'), indicator = True)

# %%
men0408.loc[men0408['_merge'] == 'left_only']
# Out:
#                        Athlete  Medals_2004  Medals_2008     _merge
# 1                  THORPE, Ian          4.0          NaN  left_only
# 2             SCHOEMAN, Roland          3.0          NaN  left_only
# 7   VAN DEN HOOGENBAND, Pieter          3.0          NaN  left_only
# 9               MORITA, Tomomi          2.0          NaN  left_only
# 11               ROGAN, Markus          2.0          NaN  left_only
# 13              HALL, Gary Jr.          2.0          NaN  left_only
# 15                WALKER, Neil          2.0          NaN  left_only
# 16           YAMAMOTO, Takashi          2.0          NaN  left_only
# 17          SPRENGER, Nicholas          1.0          NaN  left_only
# 18          OKUMURA, Yoshihiro          1.0          NaN  left_only
# 19              PARRY, Stephen          1.0          NaN  left_only
# 20               PEARSON, Todd          1.0          NaN  left_only
# 21              ZASTROW, Mitja          1.0          NaN  left_only
# ...

# %%
men0408.loc[men0408['_merge'] == 'left_only'].shape
# Out:
# (43, 4)

# %% [markdown]
# # Right Join without Intersection

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men0408 = men2004.merge(men2008, how = 'outer', on = 'Athlete', suffixes = ('_2004','_2008'),indicator = True)

# %%
men0408
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 0               PHELPS, Michael          8.0          8.0        both
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 3                PEIRSOL, Aaron          3.0          3.0        both
# 4                  CROCKER, Ian          3.0          1.0        both
# 5              KITAJIMA, Kosuke          3.0          3.0        both
# 6               HANSEN, Brendan          3.0          1.0        both
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 8                HACKETT, Grant          3.0          2.0        both
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 10                 LEZAK, Jason          2.0          3.0        both
# 11                ROGAN, Markus          2.0          NaN   left_only
# ...

# %%
men0408[men0408['_merge'] == 'right_only']
# Out:
#                       Athlete  Medals_2004  Medals_2008      _merge
# 59             BERNARD, Alain          NaN          3.0  right_only
# 60            SULLIVAN, Eamon          NaN          3.0  right_only
# 61        LAUTERSTEIN, Andrew          NaN          3.0  right_only
# 62              GREVERS, Matt          NaN          3.0  right_only
# 63           RICKARD, Brenton          NaN          2.0  right_only
# 64            LEVEAUX, Amaury          NaN          2.0  right_only
# 65           STOECKEL, Hayden          NaN          2.0  right_only
# 66              TARGETT, Matt          NaN          2.0  right_only
# 67              PARK, Taehwan          NaN          2.0  right_only
# 68         CIELO FILHO, Cesar          NaN          2.0  right_only
# 69         VYATCHANIN, Arkady          NaN          2.0  right_only
# 70              BRODIE, Leith          NaN          2.0  right_only
# 71        WEBER-GALE, Garrett          NaN          2.0  right_only
# ...

# %%
men0408[men0408['_merge'] == 'right_only'].shape
# Out:
# (46, 4)

# %% [markdown]
# # Left Join

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.merge(men2008, how = 'left', on = 'Athlete', suffixes = ['_2004', '_2008'], indicator = True)
# Out:
#                        Athlete  Medals_2004  Medals_2008     _merge
# 0              PHELPS, Michael            8          8.0       both
# 1                  THORPE, Ian            4          NaN  left_only
# 2             SCHOEMAN, Roland            3          NaN  left_only
# 3               PEIRSOL, Aaron            3          3.0       both
# 4                 CROCKER, Ian            3          1.0       both
# 5             KITAJIMA, Kosuke            3          3.0       both
# 6              HANSEN, Brendan            3          1.0       both
# 7   VAN DEN HOOGENBAND, Pieter            3          NaN  left_only
# 8               HACKETT, Grant            3          2.0       both
# 9               MORITA, Tomomi            2          NaN  left_only
# 10                LEZAK, Jason            2          3.0       both
# 11               ROGAN, Markus            2          NaN  left_only
# 12               KELLER, Klete            2          1.0       both
# ...

# %%
men2004.merge(men2008, how = 'left', on = 'Athlete', suffixes = ['_2004', '_2008'], indicator = True).shape
# Out:
# (59, 4)

# %% [markdown]
# # Right Join

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.merge(men2008, how = 'right', on = 'Athlete', suffixes = ('_2004','_2008'), indicator = True)
# Out:
#                 Athlete  Medals_2004  Medals_2008      _merge
# 0       PHELPS, Michael          8.0            8        both
# 1          LOCHTE, Ryan          2.0            4        both
# 2        BERNARD, Alain          NaN            3  right_only
# 3       SULLIVAN, Eamon          NaN            3  right_only
# 4   LAUTERSTEIN, Andrew          NaN            3  right_only
# 5         GREVERS, Matt          NaN            3  right_only
# 6          LEZAK, Jason          2.0            3        both
# 7          CSEH, Laszlo          1.0            3        both
# 8      KITAJIMA, Kosuke          3.0            3        both
# 9        PEIRSOL, Aaron          3.0            3        both
# 10     RICKARD, Brenton          NaN            2  right_only
# 11      LEVEAUX, Amaury          NaN            2  right_only
# 12       HACKETT, Grant          3.0            2        both
# 13     STOECKEL, Hayden          NaN            2  right_only
# ...

# %%
men2008.merge(men2004, how = 'left', on = 'Athlete', suffixes = ('_2004','_2008'),indicator = True)
# Out:
#                 Athlete  Medals_2004  Medals_2008     _merge
# 0       PHELPS, Michael            8          8.0       both
# 1          LOCHTE, Ryan            4          2.0       both
# 2        BERNARD, Alain            3          NaN  left_only
# 3       SULLIVAN, Eamon            3          NaN  left_only
# 4   LAUTERSTEIN, Andrew            3          NaN  left_only
# 5         GREVERS, Matt            3          NaN  left_only
# 6          LEZAK, Jason            3          2.0       both
# 7          CSEH, Laszlo            3          1.0       both
# 8      KITAJIMA, Kosuke            3          3.0       both
# 9        PEIRSOL, Aaron            3          3.0       both
# 10     RICKARD, Brenton            2          NaN  left_only
# 11      LEVEAUX, Amaury            2          NaN  left_only
# 12       HACKETT, Grant            2          3.0       both
# 13     STOECKEL, Hayden            2          NaN  left_only
# ...

# %% [markdown]
# # Joining on different column Lables & Indexes

# %%
men2004 = pd.read_csv('men2004_copy.csv')

# %%
men2008 = pd.read_csv('men2008_copy.csv')

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.columns = ['Name','Medals']

# %%
men2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men0408 = men2004.merge(men2008, how = 'outer', left_on = 'Name', right_on = 'Athlete', 
                       suffixes = ('_2004','_2008'), indicator = True)

# %%
men0408
# Out:
#                            Name  Medals_2004           Athlete  Medals_2008  \
# 0               PHELPS, Michael          8.0   PHELPS, Michael          8.0
# 1                   THORPE, Ian          4.0               NaN          NaN
# 2              SCHOEMAN, Roland          3.0               NaN          NaN
# 3                PEIRSOL, Aaron          3.0    PEIRSOL, Aaron          3.0
# 4                  CROCKER, Ian          3.0      CROCKER, Ian          1.0
# 5              KITAJIMA, Kosuke          3.0  KITAJIMA, Kosuke          3.0
# 6               HANSEN, Brendan          3.0   HANSEN, Brendan          1.0
# 7    VAN DEN HOOGENBAND, Pieter          3.0               NaN          NaN
# 8                HACKETT, Grant          3.0    HACKETT, Grant          2.0
# 9                MORITA, Tomomi          2.0               NaN          NaN
# 10                 LEZAK, Jason          2.0      LEZAK, Jason          3.0
# ...

# %%
men0408.Name.fillna(men0408.Athlete, inplace = True)

# %%
men0408
# Out:
#                            Name  Medals_2004           Athlete  Medals_2008  \
# 0               PHELPS, Michael          8.0   PHELPS, Michael          8.0
# 1                   THORPE, Ian          4.0               NaN          NaN
# 2              SCHOEMAN, Roland          3.0               NaN          NaN
# 3                PEIRSOL, Aaron          3.0    PEIRSOL, Aaron          3.0
# 4                  CROCKER, Ian          3.0      CROCKER, Ian          1.0
# 5              KITAJIMA, Kosuke          3.0  KITAJIMA, Kosuke          3.0
# 6               HANSEN, Brendan          3.0   HANSEN, Brendan          1.0
# 7    VAN DEN HOOGENBAND, Pieter          3.0               NaN          NaN
# 8                HACKETT, Grant          3.0    HACKETT, Grant          2.0
# 9                MORITA, Tomomi          2.0               NaN          NaN
# 10                 LEZAK, Jason          2.0      LEZAK, Jason          3.0
# ...

# %%
men0408.drop(columns = ['Athlete', '_merge'], inplace = True)

# %%
men0408
# Out:
#                            Name  Medals_2004  Medals_2008
# 0               PHELPS, Michael          8.0          8.0
# 1                   THORPE, Ian          4.0          NaN
# 2              SCHOEMAN, Roland          3.0          NaN
# 3                PEIRSOL, Aaron          3.0          3.0
# 4                  CROCKER, Ian          3.0          1.0
# 5              KITAJIMA, Kosuke          3.0          3.0
# 6               HANSEN, Brendan          3.0          1.0
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN
# 8                HACKETT, Grant          3.0          2.0
# 9                MORITA, Tomomi          2.0          NaN
# 10                 LEZAK, Jason          2.0          3.0
# 11                ROGAN, Markus          2.0          NaN
# 12                KELLER, Klete          2.0          1.0
# 13               HALL, Gary Jr.          2.0          NaN
# 14                 LOCHTE, Ryan          2.0          4.0
# ...
